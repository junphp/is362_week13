# %% [markdown]
# # WEEK 13 ASSIGMENT

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ** Create a pandas DataFrame with a subset of the columns in the dataset. You should include the column
# that indicates edible or poisonous, the column that includes odor, and at least one other column of your
# choosing. **

# %%
Location = 'https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data'
df = pd.read_csv(Location, usecols=[0,2,5])

# %% [markdown]
# ** Add meaningful names for each column **

# %%
df.columns = ["edibility","cap-surface","odor"]

# %% [markdown]
# ** Replace the codes used in the data with numeric values—for example, in the first “target” column, “e” might
# become 0 and “p” might become 1. This is because your downstream processing in Project 4 using
# scikit-learn requires that values be stored as numerics**

# %%
df["edibility"].replace(['e', 'p'], [0, 1], inplace=True)
df["cap-surface"].replace(['f','g','y','s'],[0,1,2,3], inplace=True)
df["odor"].replace(['a', 'l', 'c', 'y', 'f', 'm', 'n', 'p', 's'], [0,1,2,3,4,5,6,7,8], inplace=True)

# %%
df
# Out:
#       edibility  cap-surface  odor
# 0             0            3     0
# 1             0            3     1
# 2             1            2     7
# 3             0            3     6
# 4             0            2     0
# 5             0            3     0
# 6             0            2     1
# 7             1            2     7
# 8             0            3     0
# 9             0            2     1
# 10            0            2     0
# 11            0            3     0
# 12            1            2     7
# 13            0            0     6
# 14            0            0     6
# 15            0            0     6
# 16            1            3     7
# 17            1            2     7
# 18            1            3     7
# 19            0            3     0
# 20            1            2     7
# 21            0            2     1
# 22            0            2     0
# 23            0            3     1
# 24            1            3     7
# 25            0            2     0
# ...

# %% [markdown]
# ** Perform exploratory data analysis: show the distribution of data for each of the columns you selected **

# %%
df["edibility"].value_counts().sort_index()
# Out:
# 0    4208
# 1    3915
# Name: edibility, dtype: int64

# %%
df["cap-surface"].value_counts().sort_index()
# Out:
# 0    2320
# 1       4
# 2    3244
# 3    2555
# Name: cap-surface, dtype: int64

# %%
df["odor"].value_counts().sort_index()
# Out:
# 0     400
# 1     400
# 2     192
# 3     576
# 4    2160
# 5      36
# 6    3528
# 7     255
# 8     576
# Name: odor, dtype: int64

# %% [markdown]
#  ** show scatterplots for edible/poisonous vs. odor as well as the other column that you selected **

# %%
df.plot.scatter(x="edibility",y="odor")
plt.title('edible/poisonous vs. odor')

# %%
df.plot.scatter(x="edibility",y="cap-surface")
plt.title('edible/poisonous vs. cap-surface')
